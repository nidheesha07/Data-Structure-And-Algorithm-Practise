# %% [markdown]
# List Comprehension

# %%
a = [2, 3, 4, 5]
res = [val ** 2 for val in a]
print(res)
# Out:
# [4, 9, 16, 25]

# %%
a = [1, 2, 3, 4, 5]
res = [val for val in a if val % 2 == 0]
print(res)
# Out:
# [2, 4]

# %%
a=[1,20,3,14,5,26]
res = [val for val in a if val>10]
print(res)
# Out:
# [20, 14, 26]
