# %% [markdown]
# Creating a String

# %%
a="Hello World"
print(a)
# Out:
# Hello World

# %% [markdown]
# Accessing Characters in String

# %%
a="Hello world"
print(a[3])
# Out:
# l

# %%
a="Hello world"
print(a[-4])
# Out:
# o

# %%
a="Hello world"
print(a[:3])
# Out:
# Hel

# %%
s = "Hello World"
for char in s:
    print(char)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
s = "helloWORLD"
s = "HELLO " + s[5:]  
print(s)
# Out:
# HELLO WORLD

# %%
s = "Hello"
del s

# %%
s = "helloWORLD"
s1=s.replace("hello","HELLO ")
print(s1)
# Out:
# HELLO WORLD

# %%
s = "Hello World"
print(len(s))
# Out:
# 11

# %%
s = "Hello World"
print(s.upper())
print(s.lower())
# Out:
# HELLO WORLD
# hello world

# %%
s = " Hello World "
print(s.strip())
# Out:
# Hello World

# %%
s1 = "Hello"
s2 = "World"
print(s1 + s2)
# Out:
# HelloWorld

# %%
s = "Hello"
print(s * 3)
# Out:
# HelloHelloHello

# %%
name = "Nidhi"
age = 19
print(f"Name: {name}, Age: {age}")
# Out:
# Name: Nidhi, Age: 19

# %%
s = "Hello World"
print("Hello" in s)
print("hello" in s)
# Out:
# True
# False
