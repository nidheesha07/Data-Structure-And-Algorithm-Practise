# %%
def myFun(x=50, y):
    print("x: ", x)
    print("y: ", y)

myFun(10)
# Out:
#   Cell In[1], line 1
#     def myFun(x=50, y):
#                     ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
def total(*numbers):
    print(sum(numbers))

total(10, 20, 30)
# Out:
# 60

# %%
def total(*numbers):
    print(sum(numbers))

total(10, 20, 30)
# Out:
# 60

# %%
def print_num(n):
    if n == 0:
        return

    print(n)
    print_num(n - 1)

print_num(5)
# Out:
# 5
# 4
# 3
# 2
# 1
