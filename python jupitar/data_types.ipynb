# %%
s = 'Welcome to the World'
print(s)
print(type(s))
print(s[1])
print(s[-1])
# Out:
# Welcome to the World
# <class 'str'>
# e
# d

# %% [markdown]
# a = [1, 2, 3]
# print(a)
# b = ["Python" , "Progreamming" , 2, 3]
# print(b[3])
# print(b[-3])

# %%
a = [1, 2, 3]
print(a)
b = ["Python" , "Progreamming" , 2, 3]
print(b[3])
print(b[-3])
# Out:
# [1, 2, 3]
# 3
# Progreamming

# %%
t2 = ('Geeks', 'For', 'Geeks', 1, 2)
print(t2[3])
print(t2[-3])
# Out:
# 1
# Geeks

# %%
t2 = ('Geeks', 'For', 'Geeks', 1, 2)
t2[3]="Hello"
print(t2[3])
print(t2[-3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 t2 = ('Geeks', 'For', 'Geeks', 1, 2)
# ----> 2 t2[3]="Hello"
#       3 print(t2[3])
#       4 print(t2[-3])
#
# TypeError: 'tuple' object does not support item assignment

# %%
d = {1: 'Welocme', 2: 'To', 'a': 'Python','b': 'Python'}
print(d[1])    
print(d.get(2))
print(d['b'])
# Out:
# Welocme
# To
# Python
