# %% [markdown]
# Create a Hash Set

# %%
num = {10, 20, 30, 40}
print(num)
# Out:
# {40, 10, 20, 30}

# %% [markdown]
# Add Elements

# %%
numbers = set()

numbers.add(10)
numbers.add(20)
numbers.add(30)

print(numbers)
# Out:
# {10, 20, 30}

# %% [markdown]
# Duplicate Values Are Ignored

# %%
numbers = {10, 20, 30, 20, 10, 40}
print(numbers)
# Out:
# {40, 10, 20, 30}
